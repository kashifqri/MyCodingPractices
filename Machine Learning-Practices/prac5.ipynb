# %%
import pandas as pd
from mlxtend.feature_selection import SequentialFeatureSelector
import seaborn as sns
import matplotlib.pyplot as plt

# %%
datasets=pd.read_csv("C://Users//basit//Downloads//Salary_dataset.csv")
datasets
# Out:
#     YearsExperience  Salary
# 0               1.2   39344
# 1               1.4   46206
# 2               1.6   37732
# 3               2.1   43526
# 4               2.3   39892
# 5               3.0   56643
# 6               3.1   60151
# 7               3.3   54446
# 8               3.3   64446
# 9               3.8   57190
# 10              4.0   63219
# 11              4.1   55795
# 12              4.1   56958
# 13              4.2   57082
# 14              4.6   61112
# 15              5.0   67939
# 16              5.2   66030
# 17              5.4   83089
# 18              6.0   81364
# 19              6.1   93941
# 20              6.9   91739
# 21              7.2   98274
# 22              8.0  101303
# 23              8.3  113813
# 24              8.8  109432
# 25              9.1  105583
# 26              9.6  116970
# 27              9.7  112636
# 28             10.4  122392
# 29             10.6  121873

# %%
datasets.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
x=datasets[["YearsExperience"]]
y=datasets["Salary"]

# %%
x.ndim
# Out:
# 2

# %%
x.shape
# Out:
# (768, 8)

# %%
# from sklearn.linear_model import LogisticRegression    #for feature selection

# %%
 # ir=LogisticRegression()   #for feature selection

# %%
  # fs=SequentialFeatureSelector(ir,k_features=6,forward=True)    #for feature selection
 # fs.fit(x,y)    #for feature selection

# %%
 # fs.feature_names    #for feature selection

# %%
 # fs.k_feature_names_    #for feature selection

# %%
 # fs.k_score_       #for feature selection

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
li=LinearRegression()
li.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
li.score(x_test,y_test)
# Out:
# 0.9347210011126784

# %%
li.predict([[1.2]])
# Out:
# C:\Users\basit\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([35787.24512367])

# %%
y_pred=li.predict(x)

# %%
sns.scatterplot(x="YearsExperience",y="Salary",data=datasets)
plt.plot(datasets["YearsExperience"],y_pred,c="red")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
