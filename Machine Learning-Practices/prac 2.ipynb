# %%
import pandas as pd

# %%
datasets=pd.read_csv("C://Users//basit//Downloads//shopping_trends.csv")
datasets
#datasets.head(6)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21     NaN        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                      53.0       Kentucky    L       Gray  Winter
# 1                      64.0          Maine    L     Maroon  Winter
# ...

# %%
datasets.isnull().sum()
# Out:
# Customer ID                  0
# Age                          0
# Gender                       0
# Item Purchased               0
# Category                     0
# Purchase Amount (USD)       11
# Location                     0
# Size                         0
# Color                        0
# Season                       0
# Review Rating                9
# Subscription Status          0
# Payment Method               0
# Shipping Type                0
# Discount Applied             0
# Promo Code Used              0
# Previous Purchases           6
# Preferred Payment Method     0
# Frequency of Purchases       0
# dtype: int64

# %%
mode_value = datasets["Season"].mode()[0]
datasets["Season"] = datasets["Season"].fillna(mode_value)

# %%
en_data = datasets[["Gender","Season"]]
en_data
# Out:
#       Gender  Season
# 0       Male  Winter
# 1       Male  Winter
# 2       Male  Spring
# 3       Male  Spring
# 4       Male  Spring
# ...      ...     ...
# 3895  Female  Summer
# 3896  Female  Spring
# 3897  Female  Spring
# 3898  Female  Summer
# 3899  Female  Spring
#
# [3900 rows x 2 columns]

# %%
pd.get_dummies(en_data).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Gender_Female  3900 non-null   bool
#  1   Gender_Male    3900 non-null   bool
#  2   Season_Fall    3900 non-null   bool
#  3   Season_Spring  3900 non-null   bool
#  4   Season_Summer  3900 non-null   bool
#  5   Season_Winter  3900 non-null   bool
# dtypes: bool(6)
# memory usage: 23.0 KB

# %%
#from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
categories = [['Female', 'Male'], ['Spring','Fall', 'Winter', 'Summer']]

# %%
en_data.nunique()
# Out:
# Gender    2
# Season    4
# dtype: int64

# %%
oe=OrdinalEncoder(categories=categories)
oe.fit_transform(en_data)
#ohe=OneHotEncoder()
#ar=ohe.fit_transform(en_data).toarray()
# Out:
# array([[1., 2.],
#        [1., 2.],
#        [1., 0.],
#        ...,
#        [0., 0.],
#        [0., 3.],
#        [0., 0.]])

# %%
print(ar.shape)

# %%
#pd.DataFrame(ar,columns=["Gender_Female","Gender_Male","Season_Fall","Season_Spring","Season_Summer","Season_Winter","Extra_Column","Extra_Column"])

# %%
# Out:
# 0    1
# 1    3
# 2    8
# 3    6
# dtype: int64
