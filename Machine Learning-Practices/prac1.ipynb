# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
datasets=pd.read_csv("C://Users//basit//Downloads//shopping_trends.csv")
datasets.head(4)
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                   53.0
# 1            2   19   Male        Sweater  Clothing                   64.0
# 2            3   50   Male          Jeans  Clothing                   73.0
# 3            4   21   Male        Sandals  Footwear                   90.0
#
#         Location Size   Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L    Gray  Winter            NaN                 Yes
# 1          Maine    L  Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S  Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M  Maroon  Spring            3.5                 Yes
#
#   Payment Method  Shipping Type Discount Applied Promo Code Used  \
# 0    Credit Card        Express              Yes             Yes
# 1  Bank Transfer        Express              Yes             Yes
# ...

# %%
datasets.shape
# Out:
# (3900, 19)

# %%
datasets.isnull()
# Out:
#       Customer ID    Age  Gender  Item Purchased  Category  \
# 0           False  False   False           False     False
# 1           False  False   False           False     False
# 2           False  False   False           False     False
# 3           False  False   False           False     False
# 4           False  False   False           False     False
# ...           ...    ...     ...             ...       ...
# 3895        False  False   False           False     False
# 3896        False  False   False           False     False
# 3897        False  False   False           False     False
# 3898        False  False   False           False     False
# 3899        False  False   False           False     False
#
#       Purchase Amount (USD)  Location   Size  Color  Season  Review Rating  \
# 0                     False     False  False  False   False           True
# 1                     False     False  False  False   False          False
# ...

# %%
datasets.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               9
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          6
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
datasets.notnull().sum().sum()
# Out:
# np.int64(74074)

# %%
(datasets.isnull().sum()/datasets.shape[0])*100
# Out:
# Customer ID                 0.000000
# Age                         0.000000
# Gender                      0.000000
# Item Purchased              0.000000
# Category                    0.000000
# Location                    0.000000
# Size                        0.000000
# Color                       0.000000
# Season                      0.000000
# Review Rating               0.230769
# Subscription Status         0.000000
# Payment Method              0.000000
# Shipping Type               0.000000
# Discount Applied            0.000000
# Promo Code Used             0.000000
# Previous Purchases          0.153846
# Preferred Payment Method    0.000000
# Frequency of Purchases      0.000000
# dtype: float64

# %%
(datasets.isnull().sum().sum()/(datasets.shape[0]*datasets.shape[1]))*100
# Out:
# np.float64(0.03508771929824561)

# %%
sns.heatmap(datasets.isnull())
plt.show()

# %%
# datasets.drop(["Purchase Amount (USD)"],axis=1,inplace=True)

# %%
# datasets.dropna()

# %%
#datasets.shape

# %%
# datasets["Gender"].fillna(datasets["Gender"].mode()[0],inplace=True)

# %%
datasets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Location                  3900 non-null   object
#  6   Size                      3900 non-null   object
#  7   Color                     3900 non-null   object
#  8   Season                    3900 non-null   object
#  9   Review Rating             3891 non-null   float64
#  10  Subscription Status       3900 non-null   object
#  11  Payment Method            3900 non-null   object
#  12  Shipping Type             3900 non-null   object
# ...

# %%
datasets.select_dtypes(include="float64").columns
# Out:
# Index(['Review Rating', 'Previous Purchases'], dtype='object')

# %%
from sklearn.impute import SimpleImputer

# %%
si=SimpleImputer(strategy="mean")
ar= si.fit_transform(datasets[['Review Rating', 'Previous Purchases']])

# %%
pd.DataFrame(ar,columns=datasets.select_dtypes(include="float64").columns)
# Out:
#       Review Rating  Previous Purchases
# 0          3.749833                14.0
# 1          3.100000                 2.0
# 2          3.100000                23.0
# 3          3.500000                49.0
# 4          2.700000                31.0
# ...             ...                 ...
# 3895       4.200000                32.0
# 3896       4.500000                41.0
# 3897       2.900000                24.0
# 3898       3.800000                24.0
# 3899       3.100000                33.0
#
# [3900 rows x 2 columns]
