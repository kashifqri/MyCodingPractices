# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split

# %%
datasets=pd.read_csv(r"C://Users//basit//Downloads/placement.csv")
datasets
# Out:
#     cgpa  placement
# 0    6.8          1
# 1    5.9          0
# 2    5.3          0
# 3    7.4          1
# 4    5.8          0
# ..   ...        ...
# 95   4.3          0
# 96   4.4          0
# 97   6.7          1
# 98   6.3          1
# 99   6.2          1
#
# [100 rows x 2 columns]

# %%
sns.scatterplot(x="cgpa",y="placement",data=datasets)
plt.show()

# %%
x=datasets[["cgpa"]]
y=datasets["placement"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.svm import SVR

# %%
sm=SVR(kernel="poly")
sm.fit(x_train,y_train)
# Out:
# SVR(kernel='poly')

# %%
sm.score(x_test,y_test)
# Out:
# 0.5819802901649709

# %%
sm.score(x_train,y_train)
# Out:
# 0.6105725522225187

# %%
sns.scatterplot(x="cgpa",y="placement",data=datasets)
plt.scatter(datasets["cgpa"],sm.predict(x),color="red")
plt.show()
