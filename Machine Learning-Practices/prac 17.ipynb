# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import numpy as np

# %%
pd.set_option("display.max_rows",200)

# %%
datasets=pd.read_csv("C://Users//basit//Downloads/groceries - groceries.csv")
datasets
# Out:
#       Item(s)               Item 1               Item 2            Item 3  \
# 0           4         citrus fruit  semi-finished bread         margarine
# 1           3       tropical fruit               yogurt            coffee
# 2           1           whole milk                  NaN               NaN
# 3           4            pip fruit               yogurt      cream cheese
# 4           4     other vegetables           whole milk    condensed milk
# ...       ...                  ...                  ...               ...
# 9830       17              sausage              chicken              beef
# 9831        1    cooking chocolate                  NaN               NaN
# 9832       10              chicken         citrus fruit  other vegetables
# 9833        4  semi-finished bread        bottled water              soda
# 9834        5              chicken       tropical fruit  other vegetables
#
#                         Item 4         Item 5
# ...

# %%
type(datasets['Item 5'][0])
# Out:
# float

# %%
market = []
for i in range (0,datasets.shape[0]):
    cus = []
    for j in datasets.columns :
        if type(datasets[j][i])==str:
            cus.append(datasets[j][i])
    market.append(cus)

# %%
market
# Out:
# [['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups'],
#  ['tropical fruit', 'yogurt', 'coffee'],
#  ['whole milk'],
#  ['pip fruit', 'yogurt', 'cream cheese', 'meat spreads'],
#  ['other vegetables',
#   'whole milk',
#   'condensed milk',
#   'long life bakery product'],
#  ['whole milk', 'butter', 'yogurt', 'rice', 'abrasive cleaner'],
#  ['rolls/buns'],
#  ['other vegetables',
#   'UHT-milk',
#   'rolls/buns',
#   'bottled beer',
#   'liquor (appetizer)'],
#  ['potted plants'],
#  ['whole milk', 'cereals'],
#  ['tropical fruit',
#   'other vegetables',
#   'white bread',
#   'bottled water',
#   'chocolate'],
#  ['citrus fruit', 'tropical fruit', 'whole milk', 'butter', 'curd'],
#  ['beef'],
#  ['frankfurter', 'rolls/buns', 'soda'],
#  ['chicken', 'tropical fruit'],
#  ['butter', 'sugar', 'fruit/vegetable juice', 'newspapers'],
#  ['fruit/vegetable juice'],
#  ['packaged fruit/vegetables'],
#  ['chocolate'],
#  ['specialty bar'],
#  ['other vegetables'],
# ...

# %%
l=[]
for i in market:
    for j in i :
        l.append(j)

# %%
import collections

# %%
p=collections.Counter(l)

# %%
d = {"Item Name" : p.keys(),"Value" : p.values()}

# %%
# pd.DataFrame(d).sort_values(by=["Value"],ascending=False)

# %%
from mlxtend.preprocessing.transactionencoder import TransactionEncoder

# %%
tr = TransactionEncoder()
tr.fit(market)
# Out:
# TransactionEncoder()

# %%
df = pd.DataFrame(tr.transform(market),columns=tr.columns_)

# %%
df
# Out:
#       Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                     False     False             False             False
# 1                     False     False             False             False
# 2                     False     False             False             False
# 3                     False     False             False             False
# 4                     False     False             False             False
# ...                     ...       ...               ...               ...
# 9830                  False     False             False             False
# 9831                  False     False             False             False
# 9832                  False     False             False             False
# 9833                  False     False             False             False
# 9834                  False     False             False             False
#
#       baby cosmetics   bags  baking powder  bathroom cleaner   beef  berries  \
# ...

# %%
# from mlxtend.frequent_patterns import apriori #Aprior algorithms

# %%
# apriori(df, min_support=0.05, use_colnames=True).sort_values(by=["support"]) #Aprior algorithms

# %%
from mlxtend.frequent_patterns import fpgrowth                             #Association rule

# %%
fpgrowth(df, min_support=0.03, use_colnames=True,max_len=3).sort_values(by=["support"])      #Association rule
# Out:
#      support                             itemsets
# 28  0.031927                            (dessert)
# 30  0.032639                  (frozen vegetables)
# 27  0.032740                            (berries)
# 35  0.032740             (rolls/buns, whole milk)
# 33  0.033045         (whole milk, tropical fruit)
# 24  0.033249                     (hamburger meat)
# 1   0.033960                          (margarine)
# 18  0.034062              (fruit/vegetable juice)
# 4   0.037722                             (coffee)
# 32  0.038129                 (yogurt, whole milk)
# 37  0.038231        (whole milk, root vegetables)
# 17  0.039146                         (newspapers)
# 36  0.039553  (other vegetables, root vegetables)
# 29  0.042196                      (domestic eggs)
# 16  0.042908                            (chicken)
# 31  0.044840                      (shopping bags)
# 23  0.045043                        (brown bread)
# 12  0.045552                               (curd)
# ...
