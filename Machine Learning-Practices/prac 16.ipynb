# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_moons
import pandas as pd

# %%
x, y = make_moons(n_samples=250, noise=0.05)

# %%
df = { "data1":x[:,0],"data2":x[:,1]}

# %%
datasets=pd.DataFrame(df)

# %%
datasets
# Out:
#         data1     data2
# 0    2.026569  0.010892
# 1   -1.011268  0.098683
# 2    1.659608 -0.216644
# 3   -0.543519  0.857805
# 4   -1.014786  0.322539
# ..        ...       ...
# 245  1.218128 -0.446609
# 246 -0.782976  0.625097
# 247  0.642899 -0.474034
# 248  0.053185  0.443379
# 249  2.025818  0.469139
#
# [250 rows x 2 columns]

# %%
sns.scatterplot(x="data1",y="data2",data=datasets)
plt.show()

# %%
from sklearn.cluster import DBSCAN

# %%
db=DBSCAN(eps=0.2, min_samples=5)
datasets["predict"]=db.fit_predict(datasets)

# %%
sns.scatterplot(x="data1",y="data2",data=datasets,hue="predict")
plt.show()
