# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
datasets=pd.read_csv(r"C://Users//basit//Downloads//Social_Network_Ads.csv")
# datasets.drop(columns=["User ID", "EstimatedSalary"],inplace=True)
datasets
# Out:
#       User ID  Age  EstimatedSalary  Purchased
# 0    15624510   19            19000          0
# 1    15810944   35            20000          0
# 2    15668575   26            43000          0
# 3    15603246   27            57000          0
# 4    15804002   19            76000          0
# ..        ...  ...              ...        ...
# 395  15691863   46            41000          1
# 396  15706071   51            23000          1
# 397  15654296   50            20000          1
# 398  15755018   36            33000          0
# 399  15594041   49            36000          1
#
# [400 rows x 4 columns]

# %%
datasets["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
x=datasets.iloc[:,:-1]
y=datasets["Purchased"]

# %%
#sns.scatterplot(x="Age",y="Purchased",data=datasets)
#plt.show()

# %%
x.ndim
# Out:
# 2

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.8875

# %%
lr.predict([[15624510,19,19000]])
# Out:
# C:\Users\basit\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
sns.scatterplot(x="Age",y="Purchased",data=datasets)
sns.lineplot(x="Age",y=lr.predict(x),data=datasets)
plt.show()
