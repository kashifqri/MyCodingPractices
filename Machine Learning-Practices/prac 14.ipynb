# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
datasets=pd.read_csv(r"C://Users//basit//Downloads//Iris.csv")
datasets.head(3)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %%
datasets.drop("Species",axis=1,inplace=True)

# %%
datasets
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
sns.pairplot(data=datasets)
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
wcss=[]
for i in range (2,21):
    km=KMeans(n_clusters=i,init="k-means++")
    km.fit(datasets)
    wcss.append(km.inertia_)

# %%
plt.plot([i for i in range (2,21)],wcss,marker="o")
plt.xlabel("no of curse")
plt.xticks([i for i in range (2,21)])
plt.ylabel("wcss")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette_score(datasets,kmn.labels_)
# Out:
# np.float64(0.5815388282262188)

# %%
kmn=KMeans(n_clusters=3)
datasets["predict"]=kmn.fit_predict(datasets)

# %%
datasets
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  predict
# 0      1            5.1           3.5            1.4           0.2        1
# 1      2            4.9           3.0            1.4           0.2        1
# 2      3            4.7           3.2            1.3           0.2        1
# 3      4            4.6           3.1            1.5           0.2        1
# 4      5            5.0           3.6            1.4           0.2        1
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %%
sns.pairplot(data=datasets,hue="predict")
plt.show()

# %%
ss=[]
no_c = [j for j in range (2,21)]
for i in range (2,21):
    km1=KMeans(n_clusters=i)
    km1.fit(datasets)
    ss.append(km1.labels_)

# %%
plt.plot(no_c,ss)
plt.xlabel("no of curse")
plt.ylabel("ss")
plt.xticks(no_c)
plt.savefig("my_graph.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
